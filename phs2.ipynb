# %% [markdown]
# ## Fase 2 --- Descrição dos dados
#
# A principal contribuição desta fase é gerar familiaridade com o banco de dados, e também estatísticas descritivas úteis para todo tipo de análise.

# %% [markdown]
# #### Passo 1 -- Sumarizar estatísticas
#
# Houve um engano neste planejamento, por conta da minha falta de experiência. Não é recomendado nem mesmo útil de qualquer forma extrair dados como variância, média, assimetria ou curtose para dados de imagem. Isso se deve ao fato de que o número de atributos é grande demais para se fazer uma análise individual.

# %% [markdown]
# #### Passo 2 -- exibir gráficos do banco com dimensionalidade reduzida
#
# Também não faz sentido exibir gráficos com dimensionalidade reduzida.

# %% [markdown]
# #### Passo 3 -- "explorar os dados mais a fundo"
#
# Devido ao caráter altamente abrangente deste passo, aqui realizamos uma exploração básica que ajudou a deixar evidente algumas características dos dados.

# %%
from pysrc.loading import loadImgDataset
from pysrc.describe import *

# %%
classes, data = loadImgDataset("train")
# Out:
# Sampling images...
# Original variance: 2447.56
# Finished sampling.
# Final variance: 2407.83
# Loss: 1.62%

# %%
showSeparation(classes)
# Out:
# Number of benign cases:  1440  (54.61%)
# Number of malignant cases:  1197  (45.39%)

# %%
showOriginalImagesBenMal("train", saveDir="doc/relatorios/fase-2")
